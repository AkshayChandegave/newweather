# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df=pd.read_csv("heart_failure_clinical_records_dataset.csv")

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.head(1)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1   265000.0               1.9           130    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1

# %%
# 1 What is the distribution of age among heart failure patients in the dataset


plt.figure(figsize =(10,6))
sns.histplot(df['age'],kde=True ,color='skyblue')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequenct')
plt.show()

# %%
#insights >>In Age 50 to 70 patients Heart failure rate is more.

# %%
df['age'].value_counts().plot.pie(y=df['age'],autopct= '%1.1f%%',figsize=(12,12))
# Out:
# <Axes: ylabel='age'>

# %%
#´2 How does the death rate vary with age

#plt.figure(figsize = (10, 6))
#sns.boxplot(x = 'DEATH_EVENT', y='age', data=df)
#plt.xlabel('Death rate')
#plt.ylabel('age')
#plt.title("Boxplot of Death rate with Age")
#plt.show()

sns.scatterplot(x = 'DEATH_EVENT', y = 'age', data = df,hue='age')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='age'>

# %%
#insights >> yes, Age is most important factor in Death event

# %%
# 3 What is the percentage of male and female patients in the dataset?
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df['sex'].value_counts()
#insights >>
# 105 is female papatients
#194 is male patients
# Out:
# 1    194
# 0    105
# Name: sex, dtype: int64

# %%
df['sex'].value_counts().plot.pie(autopct='%1.1f%%',colors=['lightcoral','lightgreen'],explode=(0,0.1),startangle=90)
# Out:
# <Axes: ylabel='sex'>

# %%
#4
plt.figure(figsize =(10,6))
sns.histplot(df['age'])
plt.title('platelte count in Age ')
plt.xlabel('Age')
plt.ylabel('Plateltes')
plt.show()

# %%
#insights >> In age 60 most of patient has platelte.

# %%
df['age'].unique()
# Out:
# array([75.   , 55.   , 65.   , 50.   , 90.   , 60.   , 80.   , 62.   ,
#        45.   , 49.   , 82.   , 87.   , 70.   , 48.   , 68.   , 53.   ,
#        95.   , 58.   , 94.   , 85.   , 69.   , 72.   , 51.   , 57.   ,
#        42.   , 41.   , 67.   , 79.   , 59.   , 44.   , 63.   , 86.   ,
#        66.   , 43.   , 46.   , 61.   , 81.   , 52.   , 64.   , 40.   ,
#        60.667, 73.   , 77.   , 78.   , 54.   , 47.   , 56.   ])

# %%
plt.figure(figsize = (20, 10))
sns.boxplot(x = 'age', y='platelets', data=df)
plt.xlabel('Age')
plt.ylabel('Plat')
plt.title("Boxplot of Plateltes rate with Age")
plt.show()

sns.scatterplot(x = 'diabetes', y = 'ejection_fraction', data = df)

# %%
df['serum_creatinine']
# Out:
# 0      1.9
# 1      1.1
# 2      1.3
# 3      1.9
# 4      2.7
#       ...
# 294    1.1
# 295    1.2
# 296    0.8
# 297    1.4
# 298    1.6
# Name: serum_creatinine, Length: 299, dtype: float64

# %%
df['serum_sodium'].unique()
# Out:
# array([130, 136, 129, 137, 116, 132, 131, 138, 133, 140, 127, 121, 135,
#        134, 144, 128, 145, 142, 139, 146, 141, 143, 126, 124, 113, 125,
#        148])

# %%
#5 Is there a corealtion"on btween cr5at"n"n5 and sod"um l5v5ls "n th5 blood
fig=go.Figure()
fig.add_trace(go.Scatter(x=df.serum_sodium,y=df.serum_creatinine,mode='markers'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#inside of this is if patients has 130 plus sodium then he creatinine also.

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
#6

df['high_blood_pressure'].value_counts().plot.pie(y=df['high_blood_pressure'],autopct= '%1.1f%%',figsize=(12,12))
# Out:
# <Axes: ylabel='high_blood_pressure'>

# %%
#6
sns.countplot(x = 'high_blood_pressure', data=df)
# Out:
# <Axes: xlabel='high_blood_pressure', ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df['smoking']
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 294    1
# 295    0
# 296    0
# 297    1
# 298    1
# Name: smoking, Length: 299, dtype: int64

# %%
#sns.scatterplot(x = 'smoking', y = 'DEATH_EVENT', data = df, hue='smoking')
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
#7
selected_coulmns = ['age', 'high_blood_pressure', 'DEATH_EVENT','smoking']
sns.pairplot(df[selected_coulmns], hue ='DEATH_EVENT', palette = 'husl')

# %%
#insights >> Using mutiple columns are comapre death event.

# %%
df['DEATH_EVENT'].value_counts().plot.pie(y=df['DEATH_EVENT'],autopct= '%1.1f%%',figsize=(12,12))
# Out:
# <Axes: ylabel='DEATH_EVENT'>

# %%
#8

sns.scatterplot(x = 'DEATH_EVENT', y = 'age', data = df, hue='age')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df['diabetes'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 299 entries, 0 to 298
# Series name: diabetes
# Non-Null Count  Dtype
# --------------  -----
# 299 non-null    int64
# dtypes: int64(1)
# memory usage: 2.5 KB

# %%
df['ejection_fraction'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 299 entries, 0 to 298
# Series name: ejection_fraction
# Non-Null Count  Dtype
# --------------  -----
# 299 non-null    int64
# dtypes: int64(1)
# memory usage: 2.5 KB

# %%
#9
sns.scatterplot(x = 'diabetes', y = 'ejection_fraction', data = df)
# Out:
# <Axes: xlabel='diabetes', ylabel='ejection_fraction'>

# %%
#insights >> patient which has diabestes also suffering from ejection fraction.

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
#10
sns.scatterplot(x = 'age', y = 'serum_creatinine', data = df)
# Out:
# <Axes: xlabel='age', ylabel='serum_creatinine'>
